# %% [markdown]
# <a href="https://colab.research.google.com/github/DKLavanya/CODSOFT/blob/main/CodSoft_Task_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv('/content/advertising (1).csv')

# Check the first few rows of the dataset
print(df.head())

# Check the columns
print(df.columns)
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
df.hist(bins=15, edgecolor='black', figsize=(10, 8))
plt.suptitle('Histogram of Features', size=16)
plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(18, 5))

# Scatter plot for TV vs Sales
sns.scatterplot(data=df, x='TV', y='Sales', ax=axs[0])
axs[0].set_title('TV and Sales')

# Scatter plot for Radio vs Sales
sns.scatterplot(data=df, x='Radio', y='Sales', ax=axs[1])
axs[1].set_title('Radio and Sales')

# Scatter plot for Newspaper vs Sales
sns.scatterplot(data=df, x='Newspaper', y='Sales', ax=axs[2])
axs[2].set_title('Newspaper and Sales')

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Feature Correlation Heatmap')
plt.show()

# %%
X = df.drop(columns=['Sales'])
y = df['Sales']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = LinearRegression()

# Train the model
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# Calculate RMSE
rmse = mean_squared_error(y_test, y_pred, squared=False)
print(f'Root Mean Squared Error (RMSE): {rmse}')

# Calculate R² Score
r2 = r2_score(y_test, y_pred)
print(f'R² Score: {r2}')
# Out:
# Root Mean Squared Error (RMSE): 1.5942471691143587
# R² Score: 0.9091484341849799
